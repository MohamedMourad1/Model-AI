# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedMourad1/Model-AI/blob/main/tast_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# Now you can use TensorFlow functions and classes using the 'tf' prefix
print(tf.__version__)
# Out:
# 2.18.0

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
main_output_dir = "/content/drive/MyDrive/Kaggle_Datasets/"
os.makedirs(main_output_dir, exist_ok=True)

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()  # Verify system setup for Ultralytics training
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.1/107.7 GB disk)

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('70e2e0680e24e0c9c6ea12cf50bae3e817eb17bd16')

model = YOLO('https://hub.ultralytics.com/models/pGCRdMk4zqMGVx98MKhZ')
results = model.train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fe8d32dfb841> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO, checks, hub
#       2 checks()
#       3
#       4 hub.login('70e2e0680e24e0c9c6ea12cf50bae3e817eb17bd16')
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
hub.login('70e2e0680e24e0c9c6ea12cf50bae3e817eb17bd16')

model = YOLO('https://hub.ultralytics.com/models/pGCRdMk4zqMGVx98MKhZ')
results = model.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5691c60c4133> in <cell line: 0>()
# ----> 1 hub.login('70e2e0680e24e0c9c6ea12cf50bae3e817eb17bd16')
#       2
#       3 model = YOLO('https://hub.ultralytics.com/models/pGCRdMk4zqMGVx98MKhZ')
#       4 results = model.train()
#
# NameError: name 'hub' is not defined
